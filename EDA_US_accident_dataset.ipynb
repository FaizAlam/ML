# %% [markdown]
# <a href="https://colab.research.google.com/github/FaizAlam/ML/blob/main/EDA_US_accident_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # US Accidents Exploratory Data Analysis
#
# TODO- talk about EDA
#
# TODO- talk about the dataset (source, what it contains, how it will be helpful)
#
#
# *   Kaggle
# *   It contains 4M+ information about accidents
# *   can be useful in prevention of accidents
#
# Edits:
# * This does contain data of New York as well

# %% [markdown]
# # Downloading the dataset

# %%
pip install opendatasets --upgrade --quiet

# %%
import opendatasets as od
dataset_url = 'https://www.kaggle.com/sobhanmoosavi/us-accidents'
od.download(dataset_url)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: faizalam53
# Your Kaggle Key: ··········
# ...
# 100%|██████████| 290M/290M [00:02<00:00, 106MB/s]

# %%
datafile_name = '/content/us-accidents/US_Accidents_Dec20_Updated.csv'

# %% [markdown]
# # Data Preparing and Cleaning
#
# - Look the using Pandas
# - Look at some information about data and the columns
# - Look at the missing or incorrect values

# %%
import pandas as pd

# %%
df = pd.read_csv(datafile_name)

# %%
df
# Out:
#                 ID  Severity  ... Nautical_Twilight Astronomical_Twilight
# 0              A-1         2  ...               Day                   Day
# 1              A-2         2  ...               Day                   Day
# 2              A-3         2  ...             Night                 Night
# 3              A-4         2  ...               Day                   Day
# 4              A-5         3  ...               Day                   Day
# ...            ...       ...  ...               ...                   ...
# 2906605  A-2906606         2  ...               Day                   Day
# 2906606  A-2906607         2  ...             Night                 Night
# 2906607  A-2906608         2  ...               Day                   Day
# 2906608  A-2906609         2  ...             Night                 Night
# 2906609  A-2906610         2  ...               Day                   Day
#
# [2906610 rows x 47 columns]

# %%
len(df.columns)
# Out:
# 47

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2906610 entries, 0 to 2906609
# Data columns (total 47 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Severity               int64
#  2   Start_Time             object
#  3   End_Time               object
#  4   Start_Lat              float64
#  5   Start_Lng              float64
#  6   End_Lat                float64
#  7   End_Lng                float64
#  8   Distance(mi)           float64
#  9   Description            object
#  10  Number                 float64
#  11  Street                 object
#  12  Side                   object
#  13  City                   object
#  14  County                 object
#  15  State                  object
#  16  Zipcode                object
#  17  Country                object
#  18  Timezone               object
#  19  Airport_Code           object
#  20  Weather_Timestamp      object
# ...

# %%
df.describe()
# Out:
#            Severity     Start_Lat  ...  Wind_Speed(mph)  Precipitation(in)
# count  2.906610e+06  2.906610e+06  ...     2.599447e+06       1.605284e+06
# mean   2.288649e+00  3.653027e+01  ...     7.818111e+00       1.119459e-02
# std    5.541618e-01  5.013964e+00  ...     5.431171e+00       1.540812e-01
# min    1.000000e+00  2.455527e+01  ...     0.000000e+00       0.000000e+00
# 25%    2.000000e+00  3.366453e+01  ...     4.600000e+00       0.000000e+00
# 50%    2.000000e+00  3.609977e+01  ...     7.000000e+00       0.000000e+00
# 75%    3.000000e+00  4.037505e+01  ...     1.040000e+01       0.000000e+00
# max    4.000000e+00  4.900220e+01  ...     9.840000e+02       2.400000e+01
#
# [8 rows x 14 columns]

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
numeric_df = df.select_dtypes(include=numerics)
len(numeric_df.columns)
# Out:
# 14

# %% [markdown]
# Percentage of missing values per column

# %%
missing_percentage = df.isna().sum().sort_values(ascending = False) / len(df)
missing_percentage
# Out:
# Number                   0.650817
# Precipitation(in)        0.447713
# Wind_Chill(F)            0.407299
# Wind_Speed(mph)          0.105677
# End_Lat                  0.097303
# End_Lng                  0.097303
# Visibility(mi)           0.024798
# Weather_Condition        0.024720
# Humidity(%)              0.024520
# Temperature(F)           0.023128
# Wind_Direction           0.021838
# Pressure(in)             0.019579
# Weather_Timestamp        0.016141
# Airport_Code             0.002273
# Timezone                 0.001180
# Zipcode                  0.000383
# Nautical_Twilight        0.000038
# Astronomical_Twilight    0.000038
# Civil_Twilight           0.000038
# Sunrise_Sunset           0.000038
# City                     0.000037
# Amenity                  0.000000
# Severity                 0.000000
# Start_Time               0.000000
# End_Time                 0.000000
# Start_Lat                0.000000
# Start_Lng                0.000000
# ...

# %%
missing_percentage[missing_percentage!=0]
# Out:
# Number                   0.650817
# Precipitation(in)        0.447713
# Wind_Chill(F)            0.407299
# Wind_Speed(mph)          0.105677
# End_Lat                  0.097303
# End_Lng                  0.097303
# Visibility(mi)           0.024798
# Weather_Condition        0.024720
# Humidity(%)              0.024520
# Temperature(F)           0.023128
# Wind_Direction           0.021838
# Pressure(in)             0.019579
# Weather_Timestamp        0.016141
# Airport_Code             0.002273
# Timezone                 0.001180
# Zipcode                  0.000383
# Nautical_Twilight        0.000038
# Astronomical_Twilight    0.000038
# Civil_Twilight           0.000038
# Sunrise_Sunset           0.000038
# City                     0.000037
# dtype: float64

# %%
missing_percentage[missing_percentage!=0].plot(kind='barh')

# %% [markdown]
# We can skip those columns which have NA value more than 50% or so because they won't be helpful

# %%
df = df.drop()

# %% [markdown]
# # Exploratory analysis and visualization
#
# columns we'll analyze:
#
# 1. City
# 2. Start Time
# 3. Start Lat, Start Long
# 4. Temperature
# 5. Weather conditions
#
# can analyze others also

# %% [markdown]
# ### City Analysis

# %%
df.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
cities = df.City.unique()
len(cities)
# Out:
# 11790

# %%
cities_by_accident = df.City.value_counts()
cities_by_accident
# Out:
# Los Angeles      68411
# Houston          68265
# Charlotte        56176
# Miami            49965
# Dallas           48525
#                  ...
# Longbranch           1
# Trevor               1
# Mayfield             1
# Lansford             1
# Sinclairville        1
# Name: City, Length: 11789, dtype: int64

# %%
cities_by_accident[0:20]
# Out:
# Los Angeles      68411
# Houston          68265
# Charlotte        56176
# Miami            49965
# Dallas           48525
# Austin           38808
# Raleigh          31355
# Atlanta          29244
# Sacramento       28984
# Orlando          28092
# Nashville        25277
# Baton Rouge      25080
# Minneapolis      22469
# San Diego        22329
# Phoenix          21370
# Oklahoma City    21292
# Portland         19432
# Richmond         18343
# Seattle          17384
# Saint Paul       17266
# Name: City, dtype: int64

# %%
'New York' in cities
# Out:
# True

# %%
cities_by_accident[:20].plot(kind='barh')

# %%
import seaborn as sns

# %%
sns.set_style('darkgrid')

# %%
sns.distplot(cities_by_accident[:100])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
high_accident_cities = cities_by_accident[cities_by_accident>=1000]
less_accident_cities = cities_by_accident[cities_by_accident<1000]

# %%
len(high_accident_cities)
# Out:
# 513

# %% [markdown]
# only 513 cities out of all have accidents more than 1000

# %%
len(high_accident_cities)/len(cities)
# Out:
# 0.04351145038167939

# %% [markdown]
# only 4.3% cities have more than 1000 yearly accidents

# %%
sns.distplot(high_accident_cities)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(less_accident_cities)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# both high and less graph is similarly to that of exponential graph. Both follows some pattern. We can use log scale to analyze better

# %%
sns.histplot(high_accident_cities,log_scale=True)

# %%
sns.histplot(less_accident_cities,log_scale=True)

# %% [markdown]
# A lot of cities has 0 accidents. Which is kinda sus.

# %%
less_accident_cities[less_accident_cities<=10]
# Out:
# Huddleston         10
# Emmetsburg         10
# Madeline Plains    10
# Glenbeulah         10
# Bellows Falls      10
#                    ..
# Longbranch          1
# Trevor              1
# Mayfield            1
# Lansford            1
# Sinclairville       1
# Name: City, Length: 5005, dtype: int64

# %% [markdown]
# Almost 5000 cities have accidents <= 10

# %% [markdown]
# ### Start time analysis

# %%
df.Start_Time
# Out:
# 0          2019-05-21 08:29:55
# 1          2019-10-07 17:43:09
# 2          2020-12-13 21:53:00
# 3          2018-04-17 16:51:23
# 4          2016-08-31 17:40:49
#                   ...
# 2906605    2018-06-28 08:49:01
# 2906606    2019-01-10 02:01:01
# 2906607    2020-11-23 12:52:00
# 2906608    2019-12-29 22:38:00
# 2906609    2018-03-26 13:35:03
# Name: Start_Time, Length: 2906610, dtype: object

# %%
df.Start_Time[0]
# Out:
# '2019-05-21 08:29:55'

# %%
#converting string to datetime object
df.Start_Time = pd.to_datetime(df.Start_Time)

# %%
df.Start_Time[0]
# Out:
# Timestamp('2019-05-21 08:29:55')

# %%
sns.distplot(df.Start_Time.dt.hour,bins=24,kde=False,norm_hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **Insights from this**
# - most accidents happen between 6-9 AM(prolly people are in hurry to go to work, and also traffic would be higher) and then in evening around 2-6 PM
# - After 6 PM, number of accidents keeps decreasing till next mornig

# %%
sns.distplot(df.Start_Time.dt.dayofweek,bins=7,kde=False,norm_hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# - on weekends, no. of accidents lower
#
# Now, is the distribution of accident by hour same on weekend as that on weekdays

# %%
sunday_start_time = df.Start_Time[df.Start_Time.dt.dayofweek==6]
sns.distplot(sunday_start_time.dt.hour,bins=24,kde=False,norm_hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# - on sunday, graph is evenly distributed. More accidents happen during evening and night time

# %%
monday_start_time = df.Start_Time[df.Start_Time.dt.dayofweek==0]
sns.distplot(monday_start_time.dt.hour,bins=24,kde=False,norm_hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# - on much difference in accident distribtion between sunday and monday.

# %%
#month plot
df_2019 = df[df.Start_Time.dt.year==2019]
sns.distplot(df_2019.Start_Time.dt.month,bins=12,kde=False,norm_hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df_2018 = df[df.Start_Time.dt.year==2018]
sns.distplot(df_2018.Start_Time.dt.month,bins=12,kde=False,norm_hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# - Towards the end of the year, accidents increases.
#
# Edit:
# But when we look year by year, accidents are pretty much uniform in all months. Maybe theres not data for initial years

# %%
df_2016 = df[df.Start_Time.dt.year==2016]
sns.distplot(df_2016.Start_Time.dt.month,bins=12,kde=False,norm_hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# - yeah, there's a data lag in 2016

# %% [markdown]
# ### Start lat and long analysis

# %%
df.Start_Lat
# Out:
# 0          34.808868
# 1          35.090080
# 2          37.145730
# 3          39.110390
# 4          26.102942
#              ...
# 2906605    29.813824
# 2906606    34.068890
# 2906607    25.702200
# 2906608    40.660140
# 2906609    38.831749
# Name: Start_Lat, Length: 2906610, dtype: float64

# %%
df.Start_Lng
# Out:
# 0          -82.269157
# 1          -80.745560
# 2         -121.985052
# 3         -119.773781
# 4          -80.265091
#               ...
# 2906605    -95.399437
# 2906606   -117.342010
# 2906607    -80.335556
# 2906608   -111.952460
# 2906609   -104.748161
# Name: Start_Lng, Length: 2906610, dtype: float64

# %%
sns.scatterplot(x = df.Start_Lng, y = df.Start_Lat)

# %%
sample_df = df.sample(int(0.1*len(df)))

# %%
sns.scatterplot(x = sample_df.Start_Lng,y = sample_df.Start_Lat, size = 0.001)

# %% [markdown]
# Let try to plot these points on a map

# %%
#pip install folium
import folium
from folium.plugins import HeatMap

# %%
sample_df = df.sample(int(0.01*len(df)))

# %%
heat_data=list(zip(list(sample_df.Start_Lat),list(sample_df.Start_Lng)))

# %%
lat,lng = df.Start_Lat[0],df.Start_Lng[0]
map = folium.Map()
HeatMap(heat_data).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %% [markdown]
# ## Ask & answer questions
#
# 1. Are there more accidents in warmer or colder area
# 2. Which 5 states have the heighest number of accidents? How about per capita?
# 3. Does Newy York show up in the data ? If yes, why is accident count so low when it is the most populous city
# 4. Among the top 100 cities in number of accidents, which state they belong to
# 5. What time of the day are accidents more frequent in. - ANSWERED
# 6. Which days of the week have the most accidents.
# 7. Which months have the most accidents.
# 8. What is the trend of accidents over the year(decreasing or increasing)
# 9. When is the accidents per unit traffic the highest
#
# -> New York is at 58th position in accident's list with accidents = 7327

# %% [markdown]
# # Summary and conclusion
#
# Insights:
# - Less than 4.5% cities have more than 1000 yearly accidents
# - Number of accidents per city decreases exponentially(or increases)
# - Over 5000 cities have reported just 10 or less accidents( Need to investigate)

# %% [markdown]
# # Areas and future work
#
# - State-wise analysis of accidents
# -
